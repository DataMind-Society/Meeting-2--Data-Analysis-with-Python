# %% [markdown]
# <a href="https://colab.research.google.com/github/DataMind-Society/Meeting-2--Data-Analysis-with-Python/blob/main/Ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Exercise 1: For Loop

# %% [markdown]
# a) Sum of all numbers in a list

# %%
numbers = [3, 6, 2, 8, 4]

total = 0

for n in numbers:
    total = total + ______

print(total)

# %% [markdown]
# b) Create a new list that contains **each number multiplied by 2**.

# %%
numbers = [1, 2, 3, 4]

new_list = []

for n in numbers:
    new_list.append(________)  #.append() is a function to ADD to a list

print(new_list)

# %% [markdown]
# c) Sum of EVEN numbers between 1 and n

# %%
total = 0

for i in range(_____, _____):  #range(1st, last) and increments by 1 by default
    if i _ 2 == _____:
        total = total + i

print(total)

# %% [markdown]
# # Exercise 2: Movie Ratings Analysis
#
# You are given a dataset containing movies, their genres, and ratings.
#
# Your goal is to explore the data, answer questions, and visualize it.
#
# Fill in the missing parts of the code.

# %%
data = {
    "Movie": ["Avengers", "Frozen", "Batman", "Inception", "Toy Story"],
    "Genre": ["Action", "Animation", "Action", "Sci-Fi", "Animation"],
    "Rating": [8.4, 7.5, 8.2, 8.8, 8.3],
    "Views": [150, 120, 130, 140, 110]
}

df = pd.DataFrame(data)
df

# %% [markdown]
# 1) Display the first few rows

# %%
df.__()

# %% [markdown]
# 2) Display the **Rating** column

# %%
df[]

# %% [markdown]
# 3. Find the **average** movie rating

# %%
df[].__()

# %% [markdown]
# 4. What is the best rated movie?

# %%
df[df[] == df[].max()]

# %% [markdown]
# 5) Create a **SCATTER** plot

# %%
df.plot(
    x="______",
    y="______",
    kind="______",
    title="Views vs Ratings"
)

plt.show()
